# %% [markdown]
# ### Checks all models given in the dict

# %%
# imports
import cobra
import yaml

# config preperation
import sys # append path

sys.path.append('../scripts/')
import helperFunction as hf

config_name = 'model_config'
config_path = f'../config/{config_name}.yaml'

# load config
with open(config_path, 'r') as file:
    config = yaml.safe_load(file)

# %%
# uses validation function from cobra and stores the results in a dataframe / csv
# takes 1.30 min
import cobra
import os  
import pandas as pd
import yaml

config_name = 'model_config'
config_path = f'../config/{config_name}.yaml'

# load config
with open(config_path, 'r') as file:
    config = yaml.safe_load(file)

## load models
models = {
    'yli647_corr': config['models']['yli647_corr'], 
    'yli647_uncorr': config['models']['yli647_uncorr'], 
    'iYali4_corr': config['models']['yli4_corr'], 
    'iYali4_uncorr': config['models']['yli4_uncorr'], 
    'iYli_2.0_corr': config['models']['yli2.0_corr'], 
    #'iYli_2.0_uncorr': config['models']['yli2.0_uncorr'], 
    'iMK735_corr': config['models']['yliMK735_corr'], 
    'iMK735_uncorr': config['models']['yliMK735_uncorr'], 
    'iNL895_corr': config['models']['yliNL895_corr'],
    'iNL895_uncorr': config['models']['yliNL895_uncorr'],
    'PpaMBEL1254': config['models']['ppaMBEL1254'],
    'iYli21': config['models']['yli21'],
    'iMT1026v3': config['models']['ppa1026v3'],
    'iMT1026Chan2017': config['models']['ppa1026Chan'],
    'iLC915': config['models']['ppaiLC915'],
}

# create and store error dataframe:
error_dict = { 'Model_Name': [],
'SBML_FATAL': [],
 'SBML_ERROR': [],
 'SBML_SCHEMA_ERROR': [],
 'SBML_WARNING': [],
 'COBRA_FATAL': [],
 'COBRA_ERROR': [],
 'COBRA_WARNING': [],
 'COBRA_CHECK': []}

# iterate the models and store the errors in the error_dict
for model_name, model_path in models.items():
    # load and validate model
    model, report = cobra.io.validate_sbml_model(model_path)
    error_dict['Model_Name'].append(model_name)
    for key, value in report.items():
        error_dict[key].append(value)
error_df = pd.DataFrame.from_dict(error_dict)

os.makedirs('/'.join(config['results']['model_errors'].split('/')[0:-1]), exist_ok=True)  
# save error_df
error_df.to_csv(config['results']['model_errors'], sep='\t', index=False)

# %%
# print the error for all models
## load models
models = {
    'yli647_corr': config['models']['yli647_corr'], 
    'yli647_uncorr': config['models']['yli647_uncorr'], 
    'iYali4_corr': config['models']['yli4_corr'], 
    'iYali4_uncorr': config['models']['yli4_uncorr'], 
    'iYli_2.0_corr': config['models']['yli2.0_corr'], 
    #'iYli_2.0_uncorr': config['models']['yli2.0_uncorr'], 
    'iMK735_corr': config['models']['yliMK735_corr'], 
    'iMK735_uncorr': config['models']['yliMK735_uncorr'], 
    'iNL895_corr': config['models']['yliNL895_corr'],
    'iNL895_uncorr': config['models']['yliNL895_uncorr'],
    'PpaMBEL1254': config['models']['ppaMBEL1254'],
    'iYli21': config['models']['yli21'],
    'iMT1026v3': config['models']['ppa1026v3'],
    'iMT1026Chan2017': config['models']['ppa1026Chan'],
    'iLC915': config['models']['ppaiLC915'],
}

# iterater models dictionary
for model_name, model_path in models.items():
    # load and validate model
    model, report = cobra.io.validate_sbml_model(model_path)
    print(model_name)
    for key, value in report.items():
        if "fatal" in key.lower() or "error" in key.lower():
            print(f'{key}: {value}')
    # check if model is non type:
    if isinstance(model, type(None)):
        print('Model is NoneType')
    print('----------------------------------')
## No Error and Warning

# iYli21, iYli647 iYL: no error and no worning

## No Error but Warning
# iYali4, iYli_2.0, iMK735:
# 'No objective in listOfObjectives'
# iNL895: many reactions without any reactants or products
# iMT1026v3: Formula in the notes section is discouraged

## Error
# iMT1026Chan2017: Error in chemical formula
# Out:
# yli647_corr
# SBML_FATAL: []
# SBML_ERROR: []
# SBML_SCHEMA_ERROR: []
# COBRA_FATAL: []
# COBRA_ERROR: []
# ----------------------------------
# yli647_uncorr
# SBML_FATAL: []
# SBML_ERROR: ["E0 (Error): XML content (core, L13765); Missing required attribute; Missing a required XML attribute. The http://www.sbml.org/sbml/level2 reaction attribute 'id' is required.\n", "E1 (Error): XML content (core, L13838); Missing required attribute; Missing a required XML attribute. The http://www.sbml.org/sbml/level2 reaction attribute 'id' is required.\n", "E2 (Error): XML content (core, L13765); Missing required attribute; Missing a required XML attribute. The http://www.sbml.org/sbml/level2 reaction attribute 'id' is required.\n", "E3 (Error): XML content (core, L13838); Missing required attribute; Missing a required XML attribute. The http://www.sbml.org/sbml/level2 reaction attribute 'id' is required.\n"]
# SBML_SCHEMA_ERROR: []
# COBRA_FATAL: []
# COBRA_ERROR: ['Required attribute \'id\' cannot be found or parsed in \'<Reaction "biomass yarrowia carbon limiting">\'. with name \'biomass yarrowia carbon limiting\'']
# Model is NoneType
# ----------------------------------
# iYali4_corr
# SBML_FATAL: []
# SBML_ERROR: ["E0 (Error): SBML component consistency (fbc, L16); 'fbc:reaction' must refer to valid reaction; The value of the attribute 'fbc:reaction' of a <fluxObjective> object must be the identifier of an existing <reaction> object defined in the enclosing <model> object.\nReference: L3V1 Fbc V3, Section 3.7\n The <fluxObjective> refers to a reaction with id 'biomass_C' that does not exist within the <model>.\n"]
# SBML_SCHEMA_ERROR: []
# COBRA_FATAL: []
# COBRA_ERROR: []
# ----------------------------------
# iYali4_uncorr
# SBML_FATAL: []
# SBML_ERROR: []
# SBML_SCHEMA_ERROR: []
# COBRA_FATAL: []
# COBRA_ERROR: []
# ----------------------------------
# iYli_2.0_corr
# SBML_FATAL: []
# SBML_ERROR: []
# SBML_SCHEMA_ERROR: []
# COBRA_FATAL: []
# COBRA_ERROR: ['No objective coefficients in model. Unclear what should be optimized']
# ----------------------------------
# iMK735_corr
# SBML_FATAL: []
# SBML_ERROR: []
# SBML_SCHEMA_ERROR: []
# COBRA_FATAL: []
# COBRA_ERROR: ['No objective coefficients in model. Unclear what should be optimized']
# ----------------------------------
# iMK735_uncorr
# SBML_FATAL: []
# SBML_ERROR: []
# SBML_SCHEMA_ERROR: []
# COBRA_FATAL: []
# COBRA_ERROR: []
# ----------------------------------
# iNL895_corr
# SBML_FATAL: []
# SBML_ERROR: ["E0 (Error): SBML component consistency (core, L15045); Cannot have a reaction with neither reactants nor products; A <reaction> definition must contain at least one <speciesReference>, either in its <listOfReactants> or its <listOfProducts>. A reaction without any reactant or product species is not permitted, regardless of whether the reaction has any modifier species.\nReference: L3V1 Section 4.11.3\n The <reaction> with id 'r_0755' does not contain any reactants or products. \n", "E1 (Error): SBML component consistency (core, L20378); Cannot have a reaction with neither reactants nor products; A <reaction> definition must contain at least one <speciesReference>, either in its <listOfReactants> or its <listOfProducts>. A reaction without any reactant or product species is not permitted, regardless of whether the reaction has any modifier species.\nReference: L3V1 Section 4.11.3\n The <reaction> with id 'r_1077' does not contain any reactants or products. \n", "E2 (Error): SBML component consistency (core, L20385); Cannot have a reaction with neither reactants nor products; A <reaction> definition must contain at least one <speciesReference>, either in its <listOfReactants> or its <listOfProducts>. A reaction without any reactant or product species is not permitted, regardless of whether the reaction has any modifier species.\nReference: L3V1 Section 4.11.3\n The <reaction> with id 'r_1078' does not contain any reactants or products. \n", "E3 (Error): SBML component consistency (core, L23919); Cannot have a reaction with neither reactants nor products; A <reaction> definition must contain at least one <speciesReference>, either in its <listOfReactants> or its <listOfProducts>. A reaction without any reactant or product species is not permitted, regardless of whether the reaction has any modifier species.\nReference: L3V1 Section 4.11.3\n The <reaction> with id 'r_1314' does not contain any reactants or products. \n", "E4 (Error): SBML component consistency (core, L23926); Cannot have a reaction with neither reactants nor products; A <reaction> definition must contain at least one <speciesReference>, either in its <listOfReactants> or its <listOfProducts>. A reaction without any reactant or product species is not permitted, regardless of whether the reaction has any modifier species.\nReference: L3V1 Section 4.11.3\n The <reaction> with id 'r_1315' does not contain any reactants or products. \n", "E5 (Error): SBML component consistency (core, L23936); Cannot have a reaction with neither reactants nor products; A <reaction> definition must contain at least one <speciesReference>, either in its <listOfReactants> or its <listOfProducts>. A reaction without any reactant or product species is not permitted, regardless of whether the reaction has any modifier species.\nReference: L3V1 Section 4.11.3\n The <reaction> with id 'r_1316' does not contain any reactants or products. \n", "E6 (Error): SBML component consistency (core, L23943); Cannot have a reaction with neither reactants nor products; A <reaction> definition must contain at least one <speciesReference>, either in its <listOfReactants> or its <listOfProducts>. A reaction without any reactant or product species is not permitted, regardless of whether the reaction has any modifier species.\nReference: L3V1 Section 4.11.3\n The <reaction> with id 'r_1317' does not contain any reactants or products. \n", "E7 (Error): SBML component consistency (core, L23950); Cannot have a reaction with neither reactants nor products; A <reaction> definition must contain at least one <speciesReference>, either in its <listOfReactants> or its <listOfProducts>. A reaction without any reactant or product species is not permitted, regardless of whether the reaction has any modifier species.\nReference: L3V1 Section 4.11.3\n The <reaction> with id 'r_1318' does not contain any reactants or products. \n", "E8 (Error): SBML component consistency (core, L23957); Cannot have a reaction with ...
# SBML_SCHEMA_ERROR: []
# COBRA_FATAL: []
# COBRA_ERROR: ['No objective coefficients in model. Unclear what should be optimized']
# ----------------------------------
# iNL895_uncorr
# SBML_FATAL: []
# SBML_ERROR: []
# SBML_SCHEMA_ERROR: []
# COBRA_FATAL: []
# COBRA_ERROR: []
# ----------------------------------
# PpaMBEL1254
# SBML_FATAL: []
# SBML_ERROR: []
# SBML_SCHEMA_ERROR: []
# COBRA_FATAL: []
# COBRA_ERROR: ["'' is not a valid SBML 'SId'.", 'No objective coefficients in model. Unclear what should be optimized']
# ----------------------------------
# iYli21
# SBML_FATAL: []
# SBML_ERROR: []
# SBML_SCHEMA_ERROR: []
# COBRA_FATAL: []
# COBRA_ERROR: []
# ----------------------------------
# iMT1026v3
# SBML_FATAL: []
# SBML_ERROR: []
# SBML_SCHEMA_ERROR: []
# COBRA_FATAL: []
# COBRA_ERROR: []
# ----------------------------------
# iMT1026Chan2017
# SBML_FATAL: []
# SBML_ERROR: ["E0 (Error): SBML component consistency (fbc, L25); Chemical formula must be string; The value of attribute 'fbc:chemicalFormula' on the SBML <species> object must be set to a string consisting only of atomic names or user defined compounds and their occurrence.\nReference: L3V1 Fbc V3 Section 3.4\n Encountered '-' when expecting a capital letter. The chemicalFormula 'HO16P5Charge-6' has incorrect syntax.\n", "E1 (Error): SBML component consistency (fbc, L26); Chemical formula must be string; The value of attribute 'fbc:chemicalFormula' on the SBML <species> object must be set to a string consisting only of atomic names or user defined compounds and their occurrence.\nReference: L3V1 Fbc V3 Section 3.4\n Encountered '-' when expecting a capital letter. The chemicalFormula 'O300P100Charge-100' has incorrect syntax.\n", "E2 (Error): SBML component consistency (fbc, L29); Chemical formula must be string; The value of attribute 'fbc:chemicalFormula' on the SBML <species> object must be set to a string consisting only of atomic names or user defined compounds and their occurrence.\nReference: L3V1 Fbc V3 Section 3.4\n Encountered '-' when expecting a capital letter. The chemicalFormula 'HO7P2Charge-3' has incorrect syntax.\n", "E3 (Error): SBML component consistency (fbc, L31); Chemical formula must be string; The value of attribute 'fbc:chemicalFormula' on the SBML <species> object must be set to a string consisting only of atomic names or user defined compounds and their occurrence.\nReference: L3V1 Fbc V3 Section 3.4\n Encountered '-' when expecting a capital letter. The chemicalFormula 'HO4PCharge-2' has incorrect syntax.\n", "E4 (Error): SBML component consistency (fbc, L33); Chemical formula must be string; The value of attribute 'fbc:chemicalFormula' on the SBML <species> object must be set to a string consisting only of atomic names or user defined compounds and their occurrence.\nReference: L3V1 Fbc V3 Section 3.4\n Encountered '-' when expecting a capital letter. The chemicalFormula 'HO7P2Charge-3' has incorrect syntax.\n", "E5 (Error): SBML component consistency (fbc, L35); Chemical formula must be string; The value of attribute 'fbc:chemicalFormula' on the SBML <species> object must be set to a string consisting only of atomic names or user defined compounds and their occurrence.\nReference: L3V1 Fbc V3 Section 3.4\n Encountered '-' when expecting a capital letter. The chemicalFormula 'HO4PCharge-2' has incorrect syntax.\n", "E6 (Error): SBML component consistency (fbc, L36); Chemical formula must be string; The value of attribute 'fbc:chemicalFormula' on the SBML <species> object must be set to a string consisting only of atomic names or user defined compounds and their occurrence.\nReference: L3V1 Fbc V3 Section 3.4\n Encountered '-' when expecting a capital letter. The chemicalFormula 'C2H3N2O3Charge-1' has incorrect syntax.\n", "E7 (Error): SBML component consistency (fbc, L49); Chemical formula must be string; The value of attribute 'fbc:chemicalFormula' on the SBML <species> object must be set to a string consisting only of atomic names or user defined compounds and their occurrence.\nReference: L3V1 Fbc V3 Section 3.4\n Encountered '-' when expecting a capital letter. The chemicalFormula 'C12H16N4O7P2SCharge-2' has incorrect syntax.\n", "E8 (Error): SBML component consistency (fbc, L50); Chemical formula must be string; The value of attribute 'fbc:chemicalFormula' on the SBML <species> object must be set to a string consisting only of atomic names or user defined compounds and their occurrence.\nReference: L3V1 Fbc V3 Section 3.4\n Encountered '-' when expecting a capital letter. The chemicalFormula 'C3H3O3Charge-1' has incorrect syntax.\n", "E9 (Error): SBML component consistency (fbc, L52); Chemical formula must be string; The value of attribute 'fbc:chemicalFormula' on the SBML <species> object must be set to a string consisting only of atomic names or user defined compounds and their occurrence.\ ...
# SBML_SCHEMA_ERROR: []
# COBRA_FATAL: []
# COBRA_ERROR: ["Required attribute 'id' cannot be found or parsed in '<GeneProduct>'."]
# Model is NoneType
# ----------------------------------
# iLC915
# SBML_FATAL: []
# SBML_ERROR: []
# SBML_SCHEMA_ERROR: []
# COBRA_FATAL: []
# COBRA_ERROR: []
# ----------------------------------

# %%
# check 'PpaMBEL1254' with validation function
model, report = cobra.io.validate_sbml_model(config['models']['ppaMBEL1254'])

# for key, value in report.items():
#     if "fatal" in key.lower() or "error" in key.lower():
#         print(f'{key}: {value}')
# # is not valid SBML

# set the objective for the model and write it again (default objective: R01288)
model.objective = 'R01288'
cobra.io.write_sbml_model(model, config['models']['ppaMBEL1254'])

# %%
# iMK735_corr, iYli_2.0_corr, iNL895_corr
# config['models']['yliMK735_corr'], # biomass_C
# config['models']['yli2.0_corr'], # biomass_C
# config['models']['yliNL895_corr'], biomass_C
models = [config['models']['yliMK735_corr'], config['models']['yli2.0_corr'], config['models']['yliNL895_corr']]
for model_path in models:
    model, report = cobra.io.validate_sbml_model(model_path)
    if not isinstance(model, type(None)):
        model.objective = 'biomass_C'
        cobra.io.write_sbml_model(model, model_path)
        print(f'{model_path} is written')
    else:
        print(f'{model_path} is NoneType')
# Out:
# ../data/models/Yarrowia_lipolytica/iMK735/iMK735_corr.xml is written
# ../data/models/Yarrowia_lipolytica/iYli_2.0/iYli_2.0_corr_corr_v2.xml is written
# ../data/models/Yarrowia_lipolytica/iNL895/iNL895_corr.xml is written

# %% [markdown]
# ## Investigate Models and their properties

# %% [markdown]
# ### Number of Reactions, Metabolites, Genes and Compartments -> Table

# %%
# helfende funktionen
def numberDf(model, _modelPrefix, _outputDir, _sep, _createOutput, _verbose):
    '''Check numbers of genes, metabolites and reactions and safe them to dataframe'''
    # investigate number and print numbers
    modelName = model.name
    reacNum = len(model.reactions)
    metaboNum = len(model.metabolites)
    geneNum = len(model.genes)
    if _verbose:
        print('The {name} has {reacNum} reactions, {metaboNum} metabolites and {geneNum} genes'.format(name=modelName, reacNum=reacNum, metaboNum=metaboNum, geneNum=geneNum))
    # generate dataframe
    tupleList = [(_modelPrefix,geneNum,metaboNum,reacNum)]
    modelNumbers = pd.DataFrame(tupleList, columns=['modelName','#Genes','#Metabolites','#Reactions'])
    if _createOutput:
        if _verbose:
            print('The model numbers will be saved to a .csv file.', "Path: ", _outputDir+_modelPrefix+'_modelNumbers.csv')
        modelNumbers.to_csv(_outputDir + _modelPrefix + '_modelNumbers.csv', index=False, sep=_sep)
    return modelNumbers

# %%
iYli21_model.medium.annotations.compartment_shortlist
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 iYli21_model.medium.annotations
#
# AttributeError: 'dict' object has no attribute 'annotations'

# %%
# check the model properties and build a dataframe
seperator = '\t'

# Funktionsdefinition: numberDf(model, _modelPrefix, _outputDir, _sep, _createOutput, _verbose)
# #### TEST ####
# iYli21_model = cobra.io.read_sbml_model(config['models']['yli21'])
# test_df = numberDf(iYli21_model, 'iYli21', config['results']['model_numbers_directory'], seperator, True, True)

### next: check how to find compartment number

numberDFs = []
# iterate all models 
for model_name, model_path in models.items():
    # load and validate model
    model, report = cobra.io.validate_sbml_model(model_path)
    # check if model is nontype 
    if isinstance(model,type(None)):
        print(f'{model_name} is NoneType')
        continue
    numberDFs.append(numberDf(model,model_name, config['results']['model_numbers_directory'], seperator, True, False))

# concat all dataframes
modelNumbers = pd.concat(numberDFs)

outpath_numbers = config['results']['model_numbers_directory'] + 'workingModelNumbers.csv'
# save modelNumbers
modelNumbers.to_csv(outpath_numbers, sep='\t', index=False)
# Out:
# iMT1026Chan2017 is NoneType
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# Cell In[12], line 26
#      23 modelNumbers = pd.concat(numberDFs)
#      25 # save modelNumbers
# ---> 26 modelNumbers.to_csv(config['results']['model_numbers_directory'], sep='\t', index=False)
#      28 modelNumbers.head()
#
# File ~/Coding/BSEP22/Code/With_Bockmayr/EFM_calculation_cobamp/venv/lib/python3.8/site-packages/pandas/core/generic.py:3466, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3455 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3457 formatter = DataFrameFormatter(
#    3458     frame=df,
#    3459     header=header,
#    (...)
#    3463     decimal=decimal,
#    3464 )
# -> 3466 return DataFrameRenderer(formatter).to_csv(
#    3467     path_or_buf,
#    3468     line_terminator=line_terminator,
#    3469     sep=sep,
#    3470     encoding=encoding,
#    3471     errors=errors,
#    3472     compression=compression,
#    3473     quoting=quoting,
#    3474     columns=columns,
#    3475     index_label=index_label,
#    3476     mode=mode,
#    3477     chunksize=chunksize,
#    3478     quotechar=quotechar,
#    3479     date_format=date_format,
#    3480     doublequote=doublequote,
#    3481     escapechar=escapechar,
#    3482     storage_options=storage_options,
#    3483 )
#
# File ~/Coding/BSEP22/Code/With_Bockmayr/EFM_calculation_cobamp/venv/lib/python3.8/site-packages/pandas/io/formats/format.py:1105, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1084     created_buffer = False
#    1086 csv_formatter = CSVFormatter(
#    1087     path_or_buf=path_or_buf,
#    1088     line_terminator=line_terminator,
#    (...)
#    1103     formatter=self.fmt,
#    1104 )
# -> 1105 csv_formatter.save()
#    1107 if created_buffer:
#    1108     assert isinstance(path_or_buf, StringIO)
#
# File ~/Coding/BSEP22/Code/With_Bockmayr/EFM_calculation_cobamp/venv/lib/python3.8/site-packages/pandas/io/formats/csvs.py:237, in CSVFormatter.save(self)
#     233 """
#     234 Create the writer & save.
#     235 """
#     236 # apply compression and byte/text conversion
# --> 237 with get_handle(
#     238     self.filepath_or_buffer,
#     239     self.mode,
#     240     encoding=self.encoding,
#     241     errors=self.errors,
#     242     compression=self.compression,
#     243     storage_options=self.storage_options,
#     244 ) as handles:
#     245
#     246     # Note: self.encoding is irrelevant here
#     247     self.writer = csvlib.writer(
#     248         handles.handle,  # type: ignore[arg-type]
#     249         lineterminator=self.line_terminator,
#    (...)
#     254         quotechar=self.quotechar,
#     255     )
#     257     self._save()
#
# File ~/Coding/BSEP22/Code/With_Bockmayr/EFM_calculation_cobamp/venv/lib/python3.8/site-packages/pandas/io/common.py:702, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     697 elif isinstance(handle, str):
#     698     # Check whether the filename is to be opened in binary mode.
#     699     # Binary mode does not support 'encoding' and 'newline'.
#     700     if ioargs.encoding and "b" not in ioargs.mode:
#     701         # Encoding
# --> 702         handle = open(
#     703             handle,
#     704             ioargs.mode,
#     705             encoding=ioargs.encoding,
#     706             errors=errors,
#     707             newline="",
#     708         )
#     709     else:
#     710         # Binary mode
#     711         handle = open(handle, ioargs.mode)
#
# IsADirectoryError: [Errno 21] Is a directory: '../workflow/results/quality/'

# %% [markdown]
# ### Find reactions for Yli and Ppa models

# %%
# load models
iYli21_model = cobra.io.read_sbml_model(models['iYli21'])

# %%
# oxcaloacetate (https://www.kegg.jp/entry/C00036)
# participates in malate dehydrogenase (R533) (100% producing)
mdh = iYli21_model.reactions.get_by_id('R533')
mdh # => m77[m]: oxaloacetate[m]
# oxcaloacetate = iYli21_model.metabolites.get_by_id('m77[m]')
# # oxcaloacetate.summary() #=> 100% produced by R533
# hf.formulaWithNames(mdh) # 'NAD_C21H27N7O14P2 + (S)-malate_C4H6O5 <=> H+_p+1 + NADH_C21H29N7O14P2 + oxaloacetate_C4H4O5'
# Out:
# <Reaction R533 at 0x2a5a24ca0>
